# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df_movies=pd.read_csv('C:\\Users\\Admin\\github\\DAtA SET\\ml-latest-small\\movies.csv')
df_movies
# Load the movie data set
# Out:
#       movieId                                      title  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9737   193581  Black Butler: Book of the Atlantic (2017)
# 9738   193583               No Game No Life: Zero (2017)
# 9739   193585                               Flint (2017)
# 9740   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 1                      Adventure|Children|Fantasy
# 2                                  Comedy|Romance
# 3                            Comedy|Drama|Romance
# ...

# %%
df_movies.shape
# Shape of the movie data set
# Out:
# (9742, 3)

# %%
df_user=pd.read_csv('C:\\Users\\Admin\\github\\DAtA SET\\ml-latest-small\\ratings.csv')
df_user
# Load the rating the data set
# Out:
#         userId  movieId  rating   timestamp
# 0            1        1     4.0   964982703
# 1            1        3     4.0   964981247
# 2            1        6     4.0   964982224
# 3            1       47     5.0   964983815
# 4            1       50     5.0   964982931
# ...        ...      ...     ...         ...
# 100831     610   166534     4.0  1493848402
# 100832     610   168248     5.0  1493850091
# 100833     610   168250     5.0  1494273047
# 100834     610   168252     5.0  1493846352
# 100835     610   170875     3.0  1493846415
#
# [100836 rows x 4 columns]

# %%
df_user.shape
# SHape of the rating data set
# Out:
# (100836, 4)

# %%
#Inner Merge
df_moviedata=pd.merge(df_user,df_movies,how='inner',on='movieId')# Inner takes the intersection between two data set

# %%
df_moviedata # In this we have all the column which are available in he data set
# Out:
#         userId  movieId  rating   timestamp                             title  \
# 0            1        1     4.0   964982703                  Toy Story (1995)
# 1            5        1     4.0   847434962                  Toy Story (1995)
# 2            7        1     4.5  1106635946                  Toy Story (1995)
# 3           15        1     2.5  1510577970                  Toy Story (1995)
# 4           17        1     4.5  1305696483                  Toy Story (1995)
# ...        ...      ...     ...         ...                               ...
# 100831     610   160341     2.5  1479545749                  Bloodmoon (1997)
# 100832     610   160527     4.5  1479544998  Sympathy for the Underdog (1971)
# 100833     610   160836     3.0  1493844794                     Hazard (2005)
# 100834     610   163937     3.5  1493848789                Blair Witch (2016)
# 100835     610   163981     3.5  1493850155                         31 (2016)
#
# ...

# %%
#Merger
d_left={'pid':[101,102,103,104],'pname':['camera','mobile','laptop','watch'],'sp':[1000,2000,3000,4000]}
d_right={'pid':[101,102,105,104],'pcompany':['sony','asus','hp','rollex'],'product_color':['black','white','red','brown']}

# %%
d_left=pd.DataFrame(d_left)
d_right=pd.DataFrame(d_right)

# %%
print("-----D lEFT-----\n",d_left)
# Out:
# -----D lEFT-----
#     pid   pname    sp
# 0  101  camera  1000
# 1  102  mobile  2000
# 2  103  laptop  3000
# 3  104   watch  4000

# %%
print("-----D RIGHT-----\n",d_right)
# Out:
# -----D RIGHT-----
#     pid pcompany product_color
# 0  101     sony         black
# 1  102     asus         white
# 2  105       hp           red
# 3  104   rollex         brown

# %%
# Inner Merge: Here it will take the intersection of the two data set means ewhich are common to the data set it will take that only
df_innermerge=pd.merge(d_left,d_right,how='inner',on=['pid'])

# %%
df_innermerge
# Out:
#    pid   pname    sp pcompany product_color
# 0  101  camera  1000     sony         black
# 1  102  mobile  2000     asus         white
# 2  104   watch  4000   rollex         brown

# %%
#Outer merge 
df_outermerge=pd.merge(d_left,d_right,how='outer',on=['pid'])  # Takin out the union and give tha nan value which are not available

# %%
df_outermerge
# Out:
#    pid   pname      sp pcompany product_color
# 0  101  camera  1000.0     sony         black
# 1  102  mobile  2000.0     asus         white
# 2  103  laptop  3000.0      NaN           NaN
# 3  104   watch  4000.0   rollex         brown
# 4  105     NaN     NaN       hp           red

# %%
# Right _Merge
df_r_merge=pd.merge(d_left,d_right,how='right',on=['pid'])
df_r_merge
# Out:
#    pid   pname      sp pcompany product_color
# 0  101  camera  1000.0     sony         black
# 1  102  mobile  2000.0     asus         white
# 2  104   watch  4000.0   rollex         brown
# 3  105     NaN     NaN       hp           red

# %%
# Left _Merge
df_l_merge=pd.merge(d_left,d_right,how='left',on=['pid'])
df_l_merge
# Out:
#    pid   pname    sp pcompany product_color
# 0  101  camera  1000     sony         black
# 1  102  mobile  2000     asus         white
# 2  103  laptop  3000      NaN           NaN
# 3  104   watch  4000   rollex         brown

# %%
df_outermerge
# Out:
#    pid   pname      sp pcompany product_color
# 0  101  camera  1000.0     sony         black
# 1  102  mobile  2000.0     asus         white
# 2  103  laptop  3000.0      NaN           NaN
# 3  104   watch  4000.0   rollex         brown
# 4  105     NaN     NaN       hp           red

# %%
f_outer=df_outermerge.fillna(method='ffill')

# %%
f_outer
# Out:
#    pid   pname      sp pcompany product_color
# 0  101  camera  1000.0     sony         black
# 1  102  mobile  2000.0     asus         white
# 2  103  laptop  3000.0     asus         white
# 3  104   watch  4000.0   rollex         brown
# 4  105   watch  4000.0       hp           red

# %%
f_outer=df_outermerge.fillna(method='bfill')

# %%
f_outer
# Out:
#    pid   pname      sp pcompany product_color
# 0  101  camera  1000.0     sony         black
# 1  102  mobile  2000.0     asus         white
# 2  103  laptop  3000.0   rollex         brown
# 3  104   watch  4000.0   rollex         brown
# 4  105     NaN     NaN       hp           red

# %%
f=df_outermerge.fillna({'pname':'no info',"sp":5000,"pcompany":"no data","product_color":'green'})
f
# Out:
#    pid    pname      sp pcompany product_color
# 0  101   camera  1000.0     sony         black
# 1  102   mobile  2000.0     asus         white
# 2  103   laptop  3000.0  no data         green
# 3  104    watch  4000.0   rollex         brown
# 4  105  no info  5000.0       hp           red

# %%
# Which user has given what rating to which movie
movie_pivottable=df_moviedata.pivot_table(index='userId',columns='title',values='rating')

# %%
movie_pivottable
# Out:
# title   '71 (2014)  'Hellboy': The Seeds of Creation (2004)  \
# userId
# 1              NaN                                      NaN
# 2              NaN                                      NaN
# 3              NaN                                      NaN
# 4              NaN                                      NaN
# 5              NaN                                      NaN
# ...            ...                                      ...
# 606            NaN                                      NaN
# 607            NaN                                      NaN
# 608            NaN                                      NaN
# 609            NaN                                      NaN
# 610            4.0                                      NaN
#
# title   'Round Midnight (1986)  'Salem's Lot (2004)  \
# userId
# 1                          NaN                  NaN
# 2                          NaN                  NaN
# 3                          NaN                  NaN
# ...

# %%
data=movie_pivottable.iloc[1:2,:]

# %%
print(data)
# Out:
# title   '71 (2014)  'Hellboy': The Seeds of Creation (2004)  \
# userId
# 2              NaN                                      NaN
#
# title   'Round Midnight (1986)  'Salem's Lot (2004)  \
# userId
# 2                          NaN                  NaN
#
# title   'Til There Was You (1997)  'Tis the Season for Love (2015)  \
# userId
# 2                             NaN                              NaN
#
# title   'burbs, The (1989)  'night Mother (1986)  (500) Days of Summer (2009)  \
# userId
# 2                      NaN                   NaN                          NaN
#
# title   *batteries not included (1987)  ...  Zulu (2013)  [REC] (2007)  \
# userId                                  ...
# 2                                  NaN  ...          NaN           NaN
#
# title   [REC]² (2009)  [REC]³ 3 Génesis (2012)  \
# userId
# 2                 NaN                      NaN
#
# title   anohana: The Flower We Saw That Day - The Movie (2013)  \
# userId
# ...

# %%
#perticular movie rating
movie_name=input('enter movie name')
datamovie=movie_pivottable[movie_name]

print(datamovie.dropna())
#These user have given perticular rating to toy tory movie
# Out:
# enter movie nameToy Story (1995)
# userId
# 1      4.0
# 5      4.0
# 7      4.5
# 15     2.5
# 17     4.5
#       ...
# 606    2.5
# 607    4.0
# 608    2.5
# 609    3.0
# 610    5.0
# Name: Toy Story (1995), Length: 215, dtype: float64

# %%
df_ratings=pd.DataFrame(df_moviedata.groupby('title')['rating'].mean())
df_ratings
# Out:
#                                              rating
# title
# '71 (2014)                                 4.000000
# 'Hellboy': The Seeds of Creation (2004)    4.000000
# 'Round Midnight (1986)                     3.500000
# 'Salem's Lot (2004)                        5.000000
# 'Til There Was You (1997)                  4.000000
# ...                                             ...
# eXistenZ (1999)                            3.863636
# xXx (2002)                                 2.770833
# xXx: State of the Union (2005)             2.000000
# ¡Three Amigos! (1986)                      3.134615
# À nous la liberté (Freedom for Us) (1931)  1.000000
#
# [9719 rows x 1 columns]

# %%
df_moviedata.groupby(['title','rating']).groups
# Out:
# {("'71 (2014)", 4.0): Int64Index([100803], dtype='int64'),
#  ("'Hellboy': The Seeds of Creation (2004)",
#   4.0): Int64Index([97100], dtype='int64'),
#  ("'Round Midnight (1986)", 3.5): Int64Index([97091, 97092], dtype='int64'),
#  ("'Salem's Lot (2004)", 5.0): Int64Index([97170], dtype='int64'),
#  ("'Til There Was You (1997)", 3.0): Int64Index([89522], dtype='int64'),
#  ("'Til There Was You (1997)", 5.0): Int64Index([89523], dtype='int64'),
#  ("'Tis the Season for Love (2015)", 1.5): Int64Index([68896], dtype='int64'),
#  ("'burbs, The (1989)", 1.0): Int64Index([44280, 44284], dtype='int64'),
#  ("'burbs, The (1989)", 2.0): Int64Index([44274, 44275, 44289], dtype='int64'),
#  ("'burbs, The (1989)", 3.0): Int64Index([44276, 44279, 44283], dtype='int64'),
#  ("'burbs, The (1989)", 3.5): Int64Index([44281, 44282, 44285], dtype='int64'),
#  ("'burbs, The (1989)", 4.0): Int64Index([44277, 44278, 44286], dtype='int64'),
# ...

# %%
df_no_of_rating=pd.DataFrame(df_moviedata.groupby('title')['rating'].count()) # This is very important

# %%
# Sort tby value and sort by index
#Require such movie which have been given the highest rating
df_no_of_rating.sort_values(by='rating',ascending=False)
# Out:
#                                            rating
# title
# Forrest Gump (1994)                           329
# Shawshank Redemption, The (1994)              317
# Pulp Fiction (1994)                           307
# Silence of the Lambs, The (1991)              279
# Matrix, The (1999)                            278
# ...                                           ...
# King Solomon's Mines (1950)                     1
# King Solomon's Mines (1937)                     1
# King Ralph (1991)                               1
# King Kong Lives (1986)                          1
# À nous la liberté (Freedom for Us) (1931)       1
#
# [9719 rows x 1 columns]

# %%
# Correlation
correlation_movie=movie_pivottable.corrwith(datamovie)
print(correlation_movie)
# Out:
# title
# '71 (2014)                                        NaN
# 'Hellboy': The Seeds of Creation (2004)           NaN
# 'Round Midnight (1986)                            NaN
# 'Salem's Lot (2004)                               NaN
# 'Til There Was You (1997)                         NaN
#                                                ...
# eXistenZ (1999)                              0.333282
# xXx (2002)                                  -0.244733
# xXx: State of the Union (2005)               0.129969
# ¡Three Amigos! (1986)                       -0.387202
# À nous la liberté (Freedom for Us) (1931)         NaN
# Length: 9719, dtype: float64

# %%
df_ratings['no_of_ratings']=pd.DataFrame(df_moviedata.groupby('title')['rating'].count())

# %%
df_ratings
# Out:
#                                              rating  no_of_ratings
# title
# '71 (2014)                                 4.000000              1
# 'Hellboy': The Seeds of Creation (2004)    4.000000              1
# 'Round Midnight (1986)                     3.500000              2
# 'Salem's Lot (2004)                        5.000000              1
# 'Til There Was You (1997)                  4.000000              2
# ...                                             ...            ...
# eXistenZ (1999)                            3.863636             22
# xXx (2002)                                 2.770833             24
# xXx: State of the Union (2005)             2.000000              5
# ¡Three Amigos! (1986)                      3.134615             26
# À nous la liberté (Freedom for Us) (1931)  1.000000              1
#
# [9719 rows x 2 columns]

# %%
df_ratings.sort_values(by='no_of_ratings',ascending=False)
# Out:
#                                              rating  no_of_ratings
# title
# Forrest Gump (1994)                        4.164134            329
# Shawshank Redemption, The (1994)           4.429022            317
# Pulp Fiction (1994)                        4.197068            307
# Silence of the Lambs, The (1991)           4.161290            279
# Matrix, The (1999)                         4.192446            278
# ...                                             ...            ...
# King Solomon's Mines (1950)                3.000000              1
# King Solomon's Mines (1937)                2.500000              1
# King Ralph (1991)                          1.500000              1
# King Kong Lives (1986)                     2.000000              1
# À nous la liberté (Freedom for Us) (1931)  1.000000              1
#
# [9719 rows x 2 columns]

# %%
df_similar=pd.DataFrame(correlation_movie,columns=['Correlation'])
df_similar.sort_values('Correlation',ascending=False,inplace=True)
df_similar.head(10)
# Out:
#                                                     Correlation
# title
# Land Before Time III: The Time of the Great Giv...          1.0
# Faster Pussycat! Kill! Kill! (1965)                         1.0
# Amen. (2002)                                                1.0
# Machine Girl, The (Kataude mashin gâru) (2008)              1.0
# Waydowntown (2000)                                          1.0
# Brigadoon (1954)                                            1.0
# Project X (1987)                                            1.0
# Imitation of Life (1959)                                    1.0
# Terminal Velocity (1994)                                    1.0
# Washington Square (1997)                                    1.0

# %%
#Accessing movie title then it can not be done
df_similar.iloc[0:10,:].index
# Out:
# Index(['Land Before Time III: The Time of the Great Giving (1995)',
#        'Faster Pussycat! Kill! Kill! (1965)', 'Amen. (2002)',
#        'Machine Girl, The (Kataude mashin gâru) (2008)', 'Waydowntown (2000)',
#        'Brigadoon (1954)', 'Project X (1987)', 'Imitation of Life (1959)',
#        'Terminal Velocity (1994)', 'Washington Square (1997)'],
#       dtype='object', name='title')

# %%
df1=df_ratings.join(df_similar)
df1.sort_values(by='Correlation',ascending=False,inplace=True)
df1.head(10)
# Out:
#                                                       rating  no_of_ratings  \
# title
# Land Before Time III: The Time of the Great Giv...  2.166667              3
# Faster Pussycat! Kill! Kill! (1965)                 3.700000              5
# Amen. (2002)                                        3.833333              3
# Machine Girl, The (Kataude mashin gâru) (2008)      2.250000              2
# Waydowntown (2000)                                  3.666667              3
# Brigadoon (1954)                                    4.000000              3
# Project X (1987)                                    2.750000              2
# Imitation of Life (1959)                            3.500000              2
# Terminal Velocity (1994)                            2.750000              6
# Washington Square (1997)                            3.750000              2
#
#                                                     Correlation
# title
# ...

# %% [markdown]
# # Homework

# %%
#Q  Recommend such movie whch correlation is maximum and rating is max than 15 and 20
#st  condition corr relation maximum
#2nd condition where rating is more than 15

# %%
df_no_of_rating
# Out:
#                                            rating
# title
# '71 (2014)                                      1
# 'Hellboy': The Seeds of Creation (2004)         1
# 'Round Midnight (1986)                          2
# 'Salem's Lot (2004)                             1
# 'Til There Was You (1997)                       2
# ...                                           ...
# eXistenZ (1999)                                22
# xXx (2002)                                     24
# xXx: State of the Union (2005)                  5
# ¡Three Amigos! (1986)                          26
# À nous la liberté (Freedom for Us) (1931)       1
#
# [9719 rows x 1 columns]

# %%
df_no_of_rating.sort_values(by='rating',ascending=False)
# Out:
#                                            rating
# title
# Forrest Gump (1994)                           329
# Shawshank Redemption, The (1994)              317
# Pulp Fiction (1994)                           307
# Silence of the Lambs, The (1991)              279
# Matrix, The (1999)                            278
# ...                                           ...
# King Solomon's Mines (1950)                     1
# King Solomon's Mines (1937)                     1
# King Ralph (1991)                               1
# King Kong Lives (1986)                          1
# À nous la liberté (Freedom for Us) (1931)       1
#
# [9719 rows x 1 columns]

# %%
df2=df_no_of_rating.loc[df_no_of_rating['rating'].ge(15)]

# %%
df2
# Out:
#                                    rating
# title
# 'burbs, The (1989)                     17
# (500) Days of Summer (2009)            42
# 10 Things I Hate About You (1999)      54
# 10,000 BC (2008)                       17
# 101 Dalmatians (1996)                  47
# ...                                   ...
# Zoolander (2001)                       54
# Zootopia (2016)                        32
# eXistenZ (1999)                        22
# xXx (2002)                             24
# ¡Three Amigos! (1986)                  26
#
# [1650 rows x 1 columns]

# %%
df3=pd.DataFrame(correlation_movie,columns=['Correlation'])
df3.sort_values('Correlation',ascending=False,inplace=True)
df3.head(10)
# Out:
#                                                     Correlation
# title
# Land Before Time III: The Time of the Great Giv...          1.0
# Faster Pussycat! Kill! Kill! (1965)                         1.0
# Amen. (2002)                                                1.0
# Machine Girl, The (Kataude mashin gâru) (2008)              1.0
# Waydowntown (2000)                                          1.0
# Brigadoon (1954)                                            1.0
# Project X (1987)                                            1.0
# Imitation of Life (1959)                                    1.0
# Terminal Velocity (1994)                                    1.0
# Washington Square (1997)                                    1.0

# %%
df4=pd.merge(df3,df2,how='inner',on='title')

# %%
df5=df4.loc[df4['rating'].ge(15)]

# %%
df5.head(10)
# Out:
#                                                     Correlation  rating
# title
# Toy Story (1995)                                       1.000000     215
# The Nice Guys (2016)                                   0.968694      15
# 22 Jump Street (2014)                                  0.913282      19
# Untitled Spider-Man Reboot (2017)                      0.898497      16
# Darjeeling Limited, The (2007)                         0.868810      21
# Let the Right One In (Låt den rätte komma in) (...     0.832835      17
# Thor: Ragnarok (2017)                                  0.818393      20
# Ghost Dog: The Way of the Samurai (1999)               0.816100      19
# Paper, The (1994)                                      0.805735      21
# 21 Grams (2003)                                        0.793611      25

# %% [markdown]
# # These are the top 10 movies with high correlation and rating

# %%
df6=df3.join(df2)

# %%
df6
# Out:
#                                                     Correlation  rating
# title
# Land Before Time III: The Time of the Great Giv...          1.0     NaN
# Faster Pussycat! Kill! Kill! (1965)                         1.0     NaN
# Amen. (2002)                                                1.0     NaN
# Machine Girl, The (Kataude mashin gâru) (2008)              1.0     NaN
# Waydowntown (2000)                                          1.0     NaN
# ...                                                         ...     ...
# Zulu (2013)                                                 NaN     NaN
# [REC]² (2009)                                               NaN     NaN
# [REC]³ 3 Génesis (2012)                                     NaN     NaN
# anohana: The Flower We Saw That Day - The Movie...          NaN     NaN
# À nous la liberté (Freedom for Us) (1931)                   NaN     NaN
#
# [9719 rows x 2 columns]

# %%
df6.sort_values(by='rating',ascending=True)
# Out:
#                                                     Correlation  rating
# title
# Fallen (1998)                                         -0.375972    15.0
# Seven Psychopaths (2012)                               0.572248    15.0
# Out of Africa (1985)                                   0.265908    15.0
# Before Sunset (2004)                                   0.264575    15.0
# General's Daughter, The (1999)                        -0.413569    15.0
# ...                                                         ...     ...
# Zulu (2013)                                                 NaN     NaN
# [REC]² (2009)                                               NaN     NaN
# [REC]³ 3 Génesis (2012)                                     NaN     NaN
# anohana: The Flower We Saw That Day - The Movie...          NaN     NaN
# À nous la liberté (Freedom for Us) (1931)                   NaN     NaN
#
# [9719 rows x 2 columns]

# %%
df6
# Out:
#                                                     Correlation  rating
# title
# Land Before Time III: The Time of the Great Giv...          1.0     NaN
# Faster Pussycat! Kill! Kill! (1965)                         1.0     NaN
# Amen. (2002)                                                1.0     NaN
# Machine Girl, The (Kataude mashin gâru) (2008)              1.0     NaN
# Waydowntown (2000)                                          1.0     NaN
# ...                                                         ...     ...
# Zulu (2013)                                                 NaN     NaN
# [REC]² (2009)                                               NaN     NaN
# [REC]³ 3 Génesis (2012)                                     NaN     NaN
# anohana: The Flower We Saw That Day - The Movie...          NaN     NaN
# À nous la liberté (Freedom for Us) (1931)                   NaN     NaN
#
# [9719 rows x 2 columns]

# %% [markdown]
# #  JOINS

# %%
left = pd.DataFrame({
   'id':[1,2,3,4,5],
   'Name': ['Alex', 'Amy', 'Allen', 'Alice', 'Ayoung'],
   'subject_id':['sub1','sub2','sub4','sub6','sub5']})

# %%
right = pd.DataFrame(
   {'id':[1,2,3,4,5],
   'Name': ['Billy', 'Brian', 'Bran', 'Bryce', 'Betty'],
   'subject_id':['sub2','sub4','sub3','sub6','sub5']})

# %%
print (left)

# %%
print(right)

# %%
# Merge two dataframe on 'id'

# %%
pd.merge(left,right,on='id')

# %%
# Merge two dataframe on multiple keys

# %%
 pd.merge(left,right,on=['id','subject_id'])

# %%
#Merge using how argument

# %%
pd.merge(left, right, on='subject_id', how='left')

# %%
pd.merge(left, right, on='subject_id', how='right')

# %%
pd.merge(left, right, on='subject_id', how='outer')

# %%
pd.merge(left, right, on='subject_id', how='inner')

# %% [markdown]
# #  Working with movies data set

# %%
df_movie_data=pd.merge(df_user,df_movies,how='inner',on=['movieId'])
df_movie_data

# %%
movie_pivottable=df_movie_data.pivot_table(index='userId',columns='title',values='rating')
movie_pivottable

# %%
data=movie_pivottable.iloc[1:2,:]

# %%
data

# %%
moviename=input('enter the movie name')
datamovie=movie_pivottable[moviename]

print(datamovie.dropna())

# %%
df_movie_data.groupby(['title','rating']).groups

# %% [markdown]
# # Group by

# %%
ipl_data={'Teams':['dd','csk','dc','mi','p1','srh','mi','csk'],'rank':[1,2,3,4,1,2,3,4],'year':[2014,2014,2015,2016,2013,2017,2015,2012]}
ipl_data

# %%
#Convert to data frame
ipl_data=pd.DataFrame(ipl_data)

# %%
ipl_data

# %%
group1=ipl_data.groupby('Teams')
group1

# %%
group1.groups

# %%
group2=ipl_data.groupby('year')
group2

# %%
group2.groups

# %%
# Grouping more than on parameter   on the basis of year and team
group3=ipl_data.groupby(['Teams','year'])
group3

# %%
group3.groups

# %%
group4=ipl_data.groupby('year')
for name, group in group4:
    print(group)

# %%
group4.get_group(2014)

# %%
# Using mathematical formula
group4['rank'].agg(np.mean)

# %%
# Using mathematical formula using list
group4['rank'].agg([np.mean,np.sum,np.max])

# %%
# No of movie which has high rating

# %%
df_no_of_rating=pd.DataFrame(df_movie_data.groupby('title')['ratings']).count())

# %%
# Correlation
moviename=input('enter the movie name')
datamovie=movie_pivottable[moviename]

print(datamovie.dropna())

# %%
# Correlation
corr_movie=movie_pivottable(datamovie)
#print(corr_movie)
df_similar_movie=pd.DataFrame(corr_movie,columns=['Correlation'])
df_similar_movie.sort_values('corr_movie',ascending=False,inplace=True)
df_similar_movie.head()

# %%
df_ratings['numbers_of_ratings']=pd.DataFrame(df_movie_data.groupby('title')['rating'].count())
